# %% [markdown]
# # 简介

# %% [markdown]
# # TSP问题
#
# 蚁群算法最早用来求解TSP问题，并且表现出了很大的优越性，因为它分布式特性，鲁棒性强并且容易与其它算法结合，但是同时也存在这收敛速度慢，容易陷入局部最优（local optimal）等缺点。
#
# TSP问题（Travel Salesperson Problem，即旅行商问题或者称为中国邮递员问题），是一种NP-hard问题，此类问题用一般的算法是很难得到最优解的，所以一般需要借助一些启发式算法求解，例如遗传算法（GA），蚁群算法（ACO），微粒群算法（PSO）等等。
#
# TSP问题（旅行商问题）是指旅行家要旅行n个城市，要求各个城市经历且仅经历一次 然后回到出发城市，并要求所走的路程最短。
#
# 一个TSP问题可以表达为：求解遍历图G=(V,E,C)，所有的节点一次并且回到起始节点，使得连接这些节点的路径成本最低。

# %%
# -*- coding: utf-8 -*-
import random
import copy
import time
import sys
import math
import tkinter #//GUI模块
import threading
from functools import reduce


# 参数
'''
ALPHA:信息启发因子，值越大，则蚂蚁选择之前走过的路径可能性就越大
      ，值越小，则蚁群搜索范围就会减少，容易陷入局部最优
BETA:Beta值越大，蚁群越就容易选择局部较短路径，这时算法收敛速度会
     加快，但是随机性不高，容易得到局部的相对最优
'''
(ALPHA, BETA, RHO, Q) = (1.0,2.0,0.5,100.0)
# 城市数，蚁群
(city_num, ant_num) = (50,50)
# 如下是所有城市的xy坐标。
distance_x = [
    178,272,176,171,650,499,267,703,408,437,491,74,532,
    416,626,42,271,359,163,508,229,576,147,560,35,714,
    757,517,64,314,675,690,391,628,87,240,705,699,258,
    428,614,36,360,482,666,597,209,201,492,294]
distance_y = [
    170,395,198,151,242,556,57,401,305,421,267,105,525,
    381,244,330,395,169,141,380,153,442,528,329,232,48,
    498,265,343,120,165,50,433,63,491,275,348,222,288,
    490,213,524,244,114,104,552,70,425,227,331]
#城市距离和信息素，都是二维数组
distance_graph = [ [0.0 for col in range(city_num)] for raw in range(city_num)]
pheromone_graph = [ [1.0 for col in range(city_num)] for raw in range(city_num)]



#----------- 蚂蚁 -----------
class Ant(object):

    # 初始化
    def __init__(self,ID):

        self.ID = ID                 # ID
        self.__clean_data()          # 随机初始化出生点

    # 初始数据
    def __clean_data(self):

        self.path = []               # 当前蚂蚁的路径           
        self.total_distance = 0.0    # 当前路径的总距离
        self.move_count = 0          # 移动次数
        self.current_city = -1       # 当前停留的城市
        self.open_table_city = [True for i in range(city_num)] # 探索城市的状态

        city_index = random.randint(0,city_num-1) # 随机初始出生点
        self.current_city = city_index
        self.path.append(city_index) # 将出生点加到路径上。
        self.open_table_city[city_index] = False # 表示这个城市已经被探索过了。
        self.move_count = 1

    # 选择下一个城市
    def __choice_next_city(self):

        next_city = -1
        select_citys_prob = [0.0 for i in range(city_num)]  #存储去下个城市的概率
        total_prob = 0.0

        # 获取去下一个城市的概率
        for i in range(city_num):
            if self.open_table_city[i]:
                try :
                    # 计算概率：与信息素浓度成正比，与距离成反比
                    select_citys_prob[i] = pow(pheromone_graph[self.current_city][i], ALPHA) * pow((1.0/distance_graph[self.current_city][i]), BETA)
                    total_prob += select_citys_prob[i]
                except ZeroDivisionError as e:
                    print ('Ant ID: {ID}, current city: {current}, target city: {target}'.format(ID = self.ID, current = self.current_city, target = i))
                    sys.exit(1)

        # 轮盘选择城市
        if total_prob > 0.0:
            # 产生一个随机概率,0.0-total_prob
            temp_prob = random.uniform(0.0, total_prob)
            for i in range(city_num):
                if self.open_table_city[i]:
                    # 轮次相减
                    temp_prob -= select_citys_prob[i]
                    if temp_prob < 0.0:
                        next_city = i
                        break

        # 未从概率产生，顺序选择一个未访问城市
        # if next_city == -1:
        #     for i in range(city_num):
        #         if self.open_table_city[i]:
        #             next_city = i
        #             break

        if (next_city == -1):
            next_city = random.randint(0, city_num - 1)
            while ((self.open_table_city[next_city]) == False):  # if==False,说明已经遍历过了
                next_city = random.randint(0, city_num - 1)

        # 返回下一个城市序号
        return next_city

    # 计算路径总距离
    def __cal_total_distance(self):

        temp_distance = 0.0

        for i in range(1, city_num):
            start, end = self.path[i], self.path[i-1]
            temp_distance += distance_graph[start][end]

        # 回路
        end = self.path[0]
        temp_distance += distance_graph[start][end]
        self.total_distance = temp_distance


    # 移动操作
    def __move(self, next_city):

        self.path.append(next_city)
        self.open_table_city[next_city] = False
        self.total_distance += distance_graph[self.current_city][next_city]
        self.current_city = next_city
        self.move_count += 1

    # 搜索路径
    def search_path(self):

        # 初始化数据
        self.__clean_data()

        # 搜素路径，遍历完所有城市为止
        while self.move_count < city_num:
            # 移动到下一个城市
            next_city =  self.__choice_next_city()
            self.__move(next_city)

        # 计算路径总长度
        self.__cal_total_distance()

#----------- TSP问题 -----------

class TSP(object):

    def __init__(self, root, width = 800, height = 600, n = city_num):

        # 创建画布
        self.root = root                               
        self.width = width      
        self.height = height
        # 城市数目初始化为city_num
        self.n = n
        # tkinter.Canvas
        self.canvas = tkinter.Canvas(
                root,
                width = self.width,
                height = self.height,
                bg = "#EBEBEB",             # 背景白色 
                xscrollincrement = 1,
                yscrollincrement = 1
            )
        self.canvas.pack(expand = tkinter.YES, fill = tkinter.BOTH)
        self.title("TSP蚁群算法(n:初始化 e:开始搜索 s:停止搜索 q:退出程序)")
        self.__r = 5
        self.__lock = threading.RLock()     # 线程锁

        self.__bindEvents()
        self.new()

        # 计算城市之间的距离
        for i in range(city_num):
            for j in range(city_num):
                temp_distance = pow((distance_x[i] - distance_x[j]), 2) + pow((distance_y[i] - distance_y[j]), 2)
                temp_distance = pow(temp_distance, 0.5)
                distance_graph[i][j] =float(int(temp_distance + 0.5))

    # 按键响应程序
    def __bindEvents(self):

        self.root.bind("q", self.quite)        # 退出程序
        self.root.bind("n", self.new)          # 初始化
        self.root.bind("e", self.search_path)  # 开始搜索
        self.root.bind("s", self.stop)         # 停止搜索

    # 更改标题
    def title(self, s):

        self.root.title(s)

    # 初始化
    def new(self, evt = None):

        # 停止线程
        self.__lock.acquire()
        self.__running = False
        self.__lock.release()

        self.clear()     # 清除信息 
        self.nodes = []  # 节点坐标
        self.nodes2 = [] # 节点对象

        # 初始化城市节点
        for i in range(len(distance_x)):
            # 在画布上随机初始坐标
            x = distance_x[i]
            y = distance_y[i]
            self.nodes.append((x, y))
            # 生成节点椭圆，半径为self.__r
            node = self.canvas.create_oval(x - self.__r,
                    y - self.__r, x + self.__r, y + self.__r,
                    fill = "#ff0000",      # 填充红色
                    outline = "#000000",   # 轮廓白色
                    tags = "node",
                )
            self.nodes2.append(node)
            # 显示坐标
            self.canvas.create_text(x,y-10,              # 使用create_text方法在坐标（302，77）处绘制文字
                    text = '('+str(x)+','+str(y)+')',    # 所绘制文字的内容
                    fill = 'black'                       # 所绘制文字的颜色为灰色
                )

        # 顺序连接城市
        #self.line(range(city_num))

        # 初始城市之间的距离和信息素
        for i in range(city_num):
            for j in range(city_num):
                pheromone_graph[i][j] = 1.0

        self.ants = [Ant(ID) for ID in range(ant_num)]  # 初始蚁群
        self.best_ant = Ant(-1)                          # 初始最优解
        self.best_ant.total_distance = 1 << 31           # 初始最大距离
        self.iter = 1                                    # 初始化迭代次数 

    # 将节点按order顺序连线
    def line(self, order):
        # 删除原线
        self.canvas.delete("line")
        def line2(i1, i2):
            p1, p2 = self.nodes[i1], self.nodes[i2]
            self.canvas.create_line(p1, p2, fill = "#000000", tags = "line")
            return i2

        # order[-1]为初始值
        reduce(line2, order, order[-1])

    # 清除画布
    def clear(self):
        for item in self.canvas.find_all():
            self.canvas.delete(item)

    # 退出程序
    def quite(self, evt):
        self.__lock.acquire()
        self.__running = False
        self.__lock.release()
        self.root.destroy()
        print (u"\n程序已退出...")
        sys.exit()

    # 停止搜索
    def stop(self, evt):
        self.__lock.acquire()
        self.__running = False
        self.__lock.release()

    # 开始搜索
    def search_path(self, evt = None):

        # 开启线程
        self.__lock.acquire()
        self.__running = True
        self.__lock.release()

        while self.__running:
            # 遍历每一只蚂蚁
            for ant in self.ants:
                # 搜索一条路径
                ant.search_path()
                # 与当前最优蚂蚁比较
                if ant.total_distance < self.best_ant.total_distance:
                    # 更新最优解
                    self.best_ant = copy.deepcopy(ant)
            # 更新信息素
            self.__update_pheromone_gragh()
            print (u"迭代次数：",self.iter,u"最佳路径总距离：",int(self.best_ant.total_distance))
            # 连线
            self.line(self.best_ant.path)
            # 设置标题
            self.title("TSP蚁群算法(n:随机初始 e:开始搜索 s:停止搜索 q:退出程序) 迭代次数: %d" % self.iter)
            # 更新画布
            self.canvas.update()
            self.iter += 1

    # 更新信息素
    def __update_pheromone_gragh(self):

        # 获取每只蚂蚁在其路径上留下的信息素
        temp_pheromone = [[0.0 for col in range(city_num)] for raw in range(city_num)]
        for ant in self.ants:
            for i in range(1,city_num):
                start, end = ant.path[i-1], ant.path[i]
                # 在路径上的每两个相邻城市间留下信息素，与路径总距离反比
                temp_pheromone[start][end] += Q / ant.total_distance
                temp_pheromone[end][start] = temp_pheromone[start][end]

        # 更新所有城市之间的信息素，旧信息素衰减加上新迭代信息素
        for i in range(city_num):
            for j in range(city_num):
                pheromone_graph[i][j] = pheromone_graph[i][j] * RHO + temp_pheromone[i][j]

    # 主循环
    def mainloop(self):
        self.root.mainloop()

#----------- 程序的入口处 -----------

if __name__ == '__main__':


    TSP(tkinter.Tk()).mainloop()
# Out:
# 迭代次数： 1 最佳路径总距离： 6622
# 迭代次数： 2 最佳路径总距离： 6356
# 迭代次数： 3 最佳路径总距离： 5978
# 迭代次数： 4 最佳路径总距离： 5978
# 迭代次数： 5 最佳路径总距离： 5563
# 迭代次数： 6 最佳路径总距离： 5080
# 迭代次数： 7 最佳路径总距离： 4556
# 迭代次数： 8 最佳路径总距离： 4239
# 迭代次数： 9 最佳路径总距离： 4239
# 迭代次数： 10 最佳路径总距离： 4239
# 迭代次数： 11 最佳路径总距离： 4147
# 迭代次数： 12 最佳路径总距离： 4069
# 迭代次数： 13 最佳路径总距离： 3977
# 迭代次数： 14 最佳路径总距离： 3977
# 迭代次数： 15 最佳路径总距离： 3977
# 迭代次数： 16 最佳路径总距离： 3930
# 迭代次数： 17 最佳路径总距离： 3930
# 迭代次数： 18 最佳路径总距离： 3930
# 迭代次数： 19 最佳路径总距离： 3930
# 迭代次数： 20 最佳路径总距离： 3930
# 迭代次数： 21 最佳路径总距离： 3929
# 迭代次数： 22 最佳路径总距离： 3929
# 迭代次数： 23 最佳路径总距离： 3929
# 迭代次数： 24 最佳路径总距离： 3929
# 迭代次数： 25 最佳路径总距离： 3910
# 迭代次数： 26 最佳路径总距离： 3910
# 迭代次数： 27 最佳路径总距离： 3910
# 迭代次数： 28 最佳路径总距离： 3910
# 迭代次数： 29 最佳路径总距离： 3855
# 迭代次数： 30 最佳路径总距离： 3855
# 迭代次数： 31 最佳路径总距离： 3855
# 迭代次数： 32 最佳路径总距离： 3855
# 迭代次数： 33 最佳路径总距离： 3855
# 迭代次数： 34 最佳路径总距离： 3855
# 迭代次数： 35 最佳路径总距离： 3855
# 迭代次数： 36 最佳路径总距离： 3855
# 迭代次数： 37 最佳路径总距离： 3855
# 迭代次数： 38 最佳路径总距离： 3855
# 迭代次数： 39 最佳路径总距离： 3855
# 迭代次数： 40 最佳路径总距离： 3855
# 迭代次数： 41 最佳路径总距离： 3855
# 迭代次数： 42 最佳路径总距离： 3855
# 迭代次数： 43 最佳路径总距离： 3855
# 迭代次数： 44 最佳路径总距离： 3855
# 迭代次数： 45 最佳路径总距离： 3855
# 迭代次数： 46 最佳路径总距离： 3855
# 迭代次数： 47 最佳路径总距离： 3855
# 迭代次数： 48 最佳路径总距离： 3855
# 迭代次数： 49 最佳路径总距离： 3843
# 迭代次数： 50 最佳路径总距离： 3843
# 迭代次数： 51 最佳路径总距离： 3843
# 迭代次数： 52 最佳路径总距离： 3843
# 迭代次数： 53 最佳路径总距离： 3843
# 迭代次数： 54 最佳路径总距离： 3843
# 迭代次数： 55 最佳路径总距离： 3843
# 迭代次数： 56 最佳路径总距离： 3843
# 迭代次数： 57 最佳路径总距离： 3843
# 迭代次数： 58 最佳路径总距离： 3843
# 迭代次数： 59 最佳路径总距离： 3843
# 迭代次数： 60 最佳路径总距离： 3843
# 迭代次数： 61 最佳路径总距离： 3843
# 迭代次数： 62 最佳路径总距离： 3843
# 迭代次数： 63 最佳路径总距离： 3843
# 迭代次数： 64 最佳路径总距离： 3843
# 迭代次数： 65 最佳路径总距离： 3843
# 迭代次数： 66 最佳路径总距离： 3843
# 迭代次数： 67 最佳路径总距离： 3843
# 迭代次数： 68 最佳路径总距离： 3843
# 迭代次数： 69 最佳路径总距离： 3843
# 迭代次数： 70 最佳路径总距离： 3843
# 迭代次数： 71 最佳路径总距离： 3843
# 迭代次数： 72 最佳路径总距离： 3843
# 迭代次数： 73 最佳路径总距离： 3843
# 迭代次数： 74 最佳路径总距离： 3843
# 迭代次数： 75 最佳路径总距离： 3843
# 迭代次数： 76 最佳路径总距离： 3843
# 迭代次数： 77 最佳路径总距离： 3843
# 迭代次数： 78 最佳路径总距离： 3843
# 迭代次数： 79 最佳路径总距离： 3843
# 迭代次数： 80 最佳路径总距离： 3843
# 迭代次数： 81 最佳路径总距离： 3843
# 迭代次数： 82 最佳路径总距离： 3843
# 迭代次数： 83 最佳路径总距离： 3843
# 迭代次数： 84 最佳路径总距离： 3843
# 迭代次数： 85 最佳路径总距离： 3843
# 迭代次数： 86 最佳路径总距离： 3843
# 迭代次数： 87 最佳路径总距离： 3843
# 迭代次数： 88 最佳路径总距离： 3843
# 迭代次数： 89 最佳路径总距离： 3843
# 迭代次数： 90 最佳路径总距离： 3843
# 迭代次数： 91 最佳路径总距离： 3843
# 迭代次数： 92 最佳路径总距离： 3843
# 迭代次数： 93 最佳路径总距离： 3843
# 迭代次数： 94 最佳路径总距离： 3843
# 迭代次数： 95 最佳路径总距离： 3843
# 迭代次数： 96 最佳路径总距离： 3843
# 迭代次数： 97 最佳路径总距离： 3843
# 迭代次数： 98 最佳路径总距离： 3843
# 迭代次数： 99 最佳路径总距离： 3843
# 迭代次数： 100 最佳路径总距离： 3843
# 迭代次数： 101 最佳路径总距离： 3843
# 迭代次数： 102 最佳路径总距离： 3843
# 迭代次数： 103 最佳路径总距离： 3817
# 迭代次数： 104 最佳路径总距离： 3817
# 迭代次数： 105 最佳路径总距离： 3817
# 迭代次数： 106 最佳路径总距离： 3817
# 迭代次数： 107 最佳路径总距离： 3817
# 迭代次数： 108 最佳路径总距离： 3817
# 迭代次数： 109 最佳路径总距离： 3817
# 迭代次数： 110 最佳路径总距离： 3817
# 迭代次数： 111 最佳路径总距离： 3817
# 迭代次数： 112 最佳路径总距离： 3817
# 迭代次数： 113 最佳路径总距离： 3817
# 迭代次数： 114 最佳路径总距离： 3817
# 迭代次数： 115 最佳路径总距离： 3817
# 迭代次数： 116 最佳路径总距离： 3817
# 迭代次数： 117 最佳路径总距离： 3799
# 迭代次数： 118 最佳路径总距离： 3799
# 迭代次数： 119 最佳路径总距离： 3799
# 迭代次数： 120 最佳路径总距离： 3799
# 迭代次数： 121 最佳路径总距离： 3799
# 迭代次数： 122 最佳路径总距离： 3687
# 迭代次数： 123 最佳路径总距离： 3687
# 迭代次数： 124 最佳路径总距离： 3687
# 迭代次数： 125 最佳路径总距离： 3687
# 迭代次数： 126 最佳路径总距离： 3687
# 迭代次数： 127 最佳路径总距离： 3687
# 迭代次数： 128 最佳路径总距离： 3687
# 迭代次数： 129 最佳路径总距离： 3687
# 迭代次数： 130 最佳路径总距离： 3687
# 迭代次数： 131 最佳路径总距离： 3687
# 迭代次数： 132 最佳路径总距离： 3687
# 迭代次数： 133 最佳路径总距离： 3687
# 迭代次数： 134 最佳路径总距离： 3687
# 迭代次数： 135 最佳路径总距离： 3687
# 迭代次数： 136 最佳路径总距离： 3687
# 迭代次数： 137 最佳路径总距离： 3687
# 迭代次数： 138 最佳路径总距离： 3687
# 迭代次数： 139 最佳路径总距离： 3687
# 迭代次数： 140 最佳路径总距离： 3687
# 迭代次数： 141 最佳路径总距离： 3687
# 迭代次数： 142 最佳路径总距离： 3687
# 迭代次数： 143 最佳路径总距离： 3687
# 迭代次数： 144 最佳路径总距离： 3687
# 迭代次数： 145 最佳路径总距离： 3687
# 迭代次数： 146 最佳路径总距离： 3687
# 迭代次数： 147 最佳路径总距离： 3687
# 迭代次数： 148 最佳路径总距离： 3687
# 迭代次数： 149 最佳路径总距离： 3687
# 迭代次数： 150 最佳路径总距离： 3687
# 迭代次数： 151 最佳路径总距离： 3687
# 迭代次数： 152 最佳路径总距离： 3687
# 迭代次数： 153 最佳路径总距离： 3687
# 迭代次数： 154 最佳路径总距离： 3687
# 迭代次数： 155 最佳路径总距离： 3687
# 迭代次数： 156 最佳路径总距离： 3687
# 迭代次数： 157 最佳路径总距离： 3687
# 迭代次数： 158 最佳路径总距离： 3687
# 迭代次数： 159 最佳路径总距离： 3687
# 迭代次数： 160 最佳路径总距离： 3687
# 迭代次数： 161 最佳路径总距离： 3687
# 迭代次数： 162 最佳路径总距离： 3687
# 迭代次数： 163 最佳路径总距离： 3687
# 迭代次数： 164 最佳路径总距离： 3687
# 迭代次数： 165 最佳路径总距离： 3687
# 迭代次数： 166 最佳路径总距离： 3687
# 迭代次数： 167 最佳路径总距离： 3687
# 迭代次数： 168 最佳路径总距离： 3687
# 迭代次数： 169 最佳路径总距离： 3687
# 迭代次数： 170 最佳路径总距离： 3687
# 迭代次数： 171 最佳路径总距离： 3687
# 迭代次数： 172 最佳路径总距离： 3687
# 迭代次数： 173 最佳路径总距离： 3687
# 迭代次数： 174 最佳路径总距离： 3687
# 迭代次数： 175 最佳路径总距离： 3687
# 迭代次数： 176 最佳路径总距离： 3687
# 迭代次数： 177 最佳路径总距离： 3687
# 迭代次数： 178 最佳路径总距离： 3687
# 迭代次数： 179 最佳路径总距离： 3687
# 迭代次数： 180 最佳路径总距离： 3687
# 迭代次数： 181 最佳路径总距离： 3687
# 迭代次数： 182 最佳路径总距离： 3687
# 迭代次数： 183 最佳路径总距离： 3687
# 迭代次数： 184 最佳路径总距离： 3687
# 迭代次数： 185 最佳路径总距离： 3687
# 迭代次数： 186 最佳路径总距离： 3687
# 迭代次数： 187 最佳路径总距离： 3687
# 迭代次数： 188 最佳路径总距离： 3687
# 迭代次数： 189 最佳路径总距离： 3687
# 迭代次数： 190 最佳路径总距离： 3687
# 迭代次数： 191 最佳路径总距离： 3687
# 迭代次数： 192 最佳路径总距离： 3687
# 迭代次数： 193 最佳路径总距离： 3687
# 迭代次数： 194 最佳路径总距离： 3687
# 迭代次数： 195 最佳路径总距离： 3687
# 迭代次数： 196 最佳路径总距离： 3687
# 迭代次数： 197 最佳路径总距离： 3687
# 迭代次数： 198 最佳路径总距离： 3687
# 迭代次数： 199 最佳路径总距离： 3687
# 迭代次数： 200 最佳路径总距离： 3687
# 迭代次数： 201 最佳路径总距离： 3687
# 迭代次数： 202 最佳路径总距离： 3687
# 迭代次数： 203 最佳路径总距离： 3687
# 迭代次数： 204 最佳路径总距离： 3687
# 迭代次数： 205 最佳路径总距离： 3687
# 迭代次数： 206 最佳路径总距离： 3687
# 迭代次数： 207 最佳路径总距离： 3687
# 迭代次数： 208 最佳路径总距离： 3687
# 迭代次数： 209 最佳路径总距离： 3687
# 迭代次数： 210 最佳路径总距离： 3687
# 迭代次数： 211 最佳路径总距离： 3687
# 迭代次数： 212 最佳路径总距离： 3687
# 迭代次数： 213 最佳路径总距离： 3687
# 迭代次数： 214 最佳路径总距离： 3687
# 迭代次数： 215 最佳路径总距离： 3687
# 迭代次数： 216 最佳路径总距离： 3687
# 迭代次数： 217 最佳路径总距离： 3687
# 迭代次数： 218 最佳路径总距离： 3687
# 迭代次数： 219 最佳路径总距离： 3687
# 迭代次数： 220 最佳路径总距离： 3687
# 迭代次数： 221 最佳路径总距离： 3687
# 迭代次数： 222 最佳路径总距离： 3687
# 迭代次数： 223 最佳路径总距离： 3687
# 迭代次数： 224 最佳路径总距离： 3687
# 迭代次数： 225 最佳路径总距离： 3687
# 迭代次数： 226 最佳路径总距离： 3687
# 迭代次数： 227 最佳路径总距离： 3687
# 迭代次数： 228 最佳路径总距离： 3687
# 迭代次数： 229 最佳路径总距离： 3687
# 迭代次数： 230 最佳路径总距离： 3687
# 迭代次数： 231 最佳路径总距离： 3687
# 迭代次数： 232 最佳路径总距离： 3687
# 迭代次数： 233 最佳路径总距离： 3687
# 迭代次数： 234 最佳路径总距离： 3687
# 迭代次数： 235 最佳路径总距离： 3687
# 迭代次数： 236 最佳路径总距离： 3687
# 迭代次数： 237 最佳路径总距离： 3687
# 迭代次数： 238 最佳路径总距离： 3687
# 迭代次数： 239 最佳路径总距离： 3687
# 迭代次数： 240 最佳路径总距离： 3687
# 迭代次数： 241 最佳路径总距离： 3687
# 迭代次数： 242 最佳路径总距离： 3687
# 迭代次数： 243 最佳路径总距离： 3687
# 迭代次数： 244 最佳路径总距离： 3687
# 迭代次数： 245 最佳路径总距离： 3687
# 迭代次数： 246 最佳路径总距离： 3687
# 迭代次数： 247 最佳路径总距离： 3687
# 迭代次数： 248 最佳路径总距离： 3687
# 迭代次数： 249 最佳路径总距离： 3687
# 迭代次数： 250 最佳路径总距离： 3687
# 迭代次数： 251 最佳路径总距离： 3687
# 迭代次数： 252 最佳路径总距离： 3687
#
# 程序已退出...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# d:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3351: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
