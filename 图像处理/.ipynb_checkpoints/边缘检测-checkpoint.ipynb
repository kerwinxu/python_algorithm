# %%
import cv2
import numpy as np
from  matplotlib import pyplot as plt


def show_opencv_img(img):
    im2 = img[:,:,::-1] 
    plt.imshow(im2)

# %%
img1 = cv2.imread('lena.jpg')
show_opencv_img(img)

# %%
# 转化为绘图图像
grey = cv2.cvtColor(img1,cv2.COLOR_RGB2GRAY)
plt.imshow(grey)  # 灰度图像，直接这样显示

# %%
# 用canny来检测边缘。
edges = cv2.Canny(img1, 100, 200)  # canny边缘检测，得不断的调节这个参数才能显示好的图像。
plt.imshow(edges)
